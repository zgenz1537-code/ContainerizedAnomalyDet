# %%
import pandas as pd

# %%
df = pd.read_csv('Data/preprocessed/Dataset1.csv')
df['Label'].value_counts().sort_index()
# Out:
# Label
# 0.0     5000
# 1.0     5000
# 2.0     5000
# 3.0      168
# 4.0      163
# 5.0       36
# 6.0      193
# 7.0      131
# 8.0      824
# 9.0       34
# 10.0      48
# 11.0    8722
# Name: count, dtype: int64

# %%
df = pd.read_csv('Data/preprocessed/Dataset2.csv')
df['Label'].value_counts().sort_index()
# Out:
# Label
# 0.0     4429
# 1.0     1668
# 2.0     2349
# 3.0      159
# 4.0      154
# 5.0       34
# 6.0      183
# 7.0      124
# 8.0      782
# 9.0       32
# 10.0      45
# 11.0    5233
# Name: count, dtype: int64

# %%
df = pd.read_csv('Data/preprocessed/Dataset3.csv')
df['Label'].value_counts().sort_index()
# Out:
# Label
# 0    53250
# 1    57634
# Name: count, dtype: int64
